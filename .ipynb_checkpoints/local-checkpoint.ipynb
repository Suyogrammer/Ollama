# %%
import ollama

response = ollama.chat(model='llama3.2', messages=[
    {
        'role': 'user',
        'content': 'Who is the greatest footballer of all time?',
    }
])

print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 import ollama
# ----> 3 response = ollama.chat(model='llama3.2', messages=[
#       4     {
#       5         'role': 'user',
#       6         'content': 'Who is the greatest footballer of all time?',
#       7     }
#       8 ])
#      10 print(response['message']['content'])
#
# AttributeError: module 'ollama' has no attribute 'chat'
