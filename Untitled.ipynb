# %%
import subprocess

# The prompt you want to send to the model
prompt = "Why is CR7 the goat?"

# Run the ollama CLI command and capture output
result = subprocess.run(
    ["ollama", "run", "llama3.2", prompt],
    capture_output=True,
    text=True
)

# Print the output from the command
print(result.stdout)
# Out:
# Cristiano Ronaldo (CR7) is widely regarded as one of the greatest soccer players of all time, and his nickname "the goat" (short for "greatest of all time") is a testament to his impressive career achievements. Here are some reasons why he's considered the GOAT:
#
# 1. **Unprecedented Success**: CR7 has won an astonishing array of titles, including:
# 	* 5 Ballon d'Or awards (2008, 2013, 2014, 2016, and 2017)
# 	* 4 UEFA Champions League titles
# 	* 3 Premier League titles
# 	* 2 La Liga titles
# 	* 1 Serie A title
# 	* 1 UEFA Nations League title
# 2. **Consistency and Longevity**: Ronaldo has maintained an elite level of performance for over two decades, playing for top clubs like Manchester United, Real Madrid, and Juventus.
# 3. **Goal-scoring records**: He holds numerous records, including:
# 	* All-time leading scorer in the UEFA Champions League with 134 goals
# 	* All-time leading scorer in the Premier League with 101 goals (as of 2022)
# ...
